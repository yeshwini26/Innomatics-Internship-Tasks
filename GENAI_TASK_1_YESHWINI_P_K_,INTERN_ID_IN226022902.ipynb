# %% [markdown]
# Task 1: Conceptual Understanding

# %% [markdown]
# 1️. What is the difference between "Love" and "love" in NLP?
#
# In NLP, "Love" and "love" are considered different words because computers treat uppercase and lowercase letters separately. This is called case sensitivity. To avoid duplication and improve text analysis, NLP preprocessing usually converts all words to lowercase.
#
# 2️. What happens if stopwords are not removed?
#
# If stopwords are not removed, the dataset will contain many common words like “is”, “the”, and “and” that do not add much meaning. This increases the size of the data and processing time. It may also reduce the efficiency of NLP models.
#
# 3️. Provide two real-world scenarios where removing stopwords can be harmful **
#
# Removing stopwords can sometimes change the actual meaning of a sentence. For example, in sentiment analysis removing the word “not” from “not good” changes the sentiment. It can also affect question-answer systems, where words like “what” or “who” are important.
#
# 4️. Explain the difference between stemming and lemmatization
#
# Stemming reduces a word to its root form by removing suffixes using simple rules, and the result may not always be a real word. Lemmatization converts a word to its correct dictionary base form using linguistic analysis. Lemmatization is usually more accurate but slower than stemming.

# %% [markdown]
# Task 2:Build Advanced Preprocessing Function

# %%
import nltk
import string
import re

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer


nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

import re

def preprocess_text(text):

    text = text.lower()

    text = re.sub(r'http\S+|www\S+', '', text)

    text = re.sub(r'\S+@\S+', '', text)

    text = re.sub(r'\d+', '', text)

    text = re.sub(r'(.)\1{2,}', r'\1', text)

    text = re.sub(r'[^\w\s]', '', text)

    text = re.sub(r'\s+', ' ', text).strip()

    tokens = text.split()

    filtered_tokens = []
    for word in tokens:
        if len(word) > 2 or word in ["no", "not"]:
            filtered_tokens.append(word)

    cleaned_text = " ".join(filtered_tokens)

    return cleaned_text
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# Task 3: Stress Testing

# %%
import re

def preprocess_text(text):

    text = text.lower()
    text = re.sub(r'http\S+|www\S+', '', text)
    text = re.sub(r'\S+@\S+', '', text)
    text = re.sub(r'\d+', '', text)
    text = re.sub(r'(.)\1{2,}', r'\1', text)
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()

    tokens = text.split()

    filtered_tokens = []
    for word in tokens:
        if len(word) > 2 or word in ["no", "not"]:
            filtered_tokens.append(word)

    cleaned_sentence = " ".join(filtered_tokens)

    return filtered_tokens, cleaned_sentence


sentences = [
    "Get 100% FREE access now!!!",
    "I absolutely looooved this product 😍😍",
    "Worst service ever... 0/10",
    "Call me at 9876543210",
    "This is THE best course!!!",
    "Visit https://openai.com now!",
    "Nooooo this is baaad!!!",
    "OK OK OK I got it",
    "Win $$$ now!!! Limited offer!!!",
    "I am not happy with this"
]


for s in sentences:
    tokens, cleaned = preprocess_text(s)

    print("Original Text:", s)
    print("Cleaned Tokens:", tokens)
    print("Cleaned Sentence:", cleaned)
    print("-"*50)
# Out:
# Original Text: Get 100% FREE access now!!!
# Cleaned Tokens: ['get', 'free', 'access', 'now']
# Cleaned Sentence: get free access now
# --------------------------------------------------
# Original Text: I absolutely looooved this product 😍😍
# Cleaned Tokens: ['absolutely', 'loved', 'this', 'product']
# Cleaned Sentence: absolutely loved this product
# --------------------------------------------------
# Original Text: Worst service ever... 0/10
# Cleaned Tokens: ['worst', 'service', 'ever']
# Cleaned Sentence: worst service ever
# --------------------------------------------------
# Original Text: Call me at 9876543210
# Cleaned Tokens: ['call']
# Cleaned Sentence: call
# --------------------------------------------------
# Original Text: This is THE best course!!!
# Cleaned Tokens: ['this', 'the', 'best', 'course']
# Cleaned Sentence: this the best course
# --------------------------------------------------
# Original Text: Visit https://openai.com now!
# ...

# %% [markdown]
# Task 4: Token Analytics

# %%
import re

def preprocess_text(text):

    text = text.lower()
    text = re.sub(r'http\S+|www\S+', '', text)
    text = re.sub(r'\S+@\S+', '', text)
    text = re.sub(r'\d+', '', text)
    text = re.sub(r'(.)\1{2,}', r'\1', text)
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()

    tokens = text.split()

    filtered_tokens = []
    for word in tokens:
        if len(word) > 2 or word in ["no", "not"]:
            filtered_tokens.append(word)

    cleaned_sentence = " ".join(filtered_tokens)

    return filtered_tokens, cleaned_sentence


sentences = [
    "Get 100% FREE access now!!!",
    "I absolutely looooved this product 😍😍",
    "Worst service ever... 0/10",
    "Call me at 9876543210",
    "This is THE best course!!!",
    "Visit https://openai.com now!",
    "Nooooo this is baaad!!!",
    "OK OK OK I got it",
    "Win $$$ now!!! Limited offer!!!",
    "I am not happy with this"
]


for s in sentences:

    tokens, cleaned = preprocess_text(s)

    total_tokens = len(tokens)
    unique_tokens = len(set(tokens))

    if total_tokens > 0:
        avg_token_length = sum(len(t) for t in tokens) / total_tokens
    else:
        avg_token_length = 0

    print("Original Text:", s)
    print("Cleaned Tokens:", tokens)
    print("Cleaned Sentence:", cleaned)
    print("Total Tokens:", total_tokens)
    print("Unique Tokens:", unique_tokens)
    print("Average Token Length:", round(avg_token_length,2))
    print("-"*60)
# Out:
# Original Text: Get 100% FREE access now!!!
# Cleaned Tokens: ['get', 'free', 'access', 'now']
# Cleaned Sentence: get free access now
# Total Tokens: 4
# Unique Tokens: 4
# Average Token Length: 4.0
# ------------------------------------------------------------
# Original Text: I absolutely looooved this product 😍😍
# Cleaned Tokens: ['absolutely', 'loved', 'this', 'product']
# Cleaned Sentence: absolutely loved this product
# Total Tokens: 4
# Unique Tokens: 4
# Average Token Length: 6.5
# ------------------------------------------------------------
# Original Text: Worst service ever... 0/10
# Cleaned Tokens: ['worst', 'service', 'ever']
# Cleaned Sentence: worst service ever
# Total Tokens: 3
# Unique Tokens: 3
# Average Token Length: 5.33
# ------------------------------------------------------------
# Original Text: Call me at 9876543210
# Cleaned Tokens: ['call']
# Cleaned Sentence: call
# Total Tokens: 1
# Unique Tokens: 1
# Average Token Length: 4.0
# ...

# %% [markdown]
# Task 5: Frequency Analysis

# %%
from collections import Counter
import re

def preprocess_text(text):

    text = text.lower()
    text = re.sub(r'http\S+|www\S+', '', text)
    text = re.sub(r'\S+@\S+', '', text)
    text = re.sub(r'\d+', '', text)
    text = re.sub(r'(.)\1{2,}', r'\1', text)
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()

    tokens = text.split()

    filtered_tokens = []
    for word in tokens:
        if len(word) > 2 or word in ["no", "not"]:
            filtered_tokens.append(word)

    return filtered_tokens


sentences = [
    "Get 100% FREE access now!!!",
    "I absolutely looooved this product 😍😍",
    "Worst service ever... 0/10",
    "Call me at 9876543210",
    "This is THE best course!!!",
    "Visit https://openai.com now!",
    "Nooooo this is baaad!!!",
    "OK OK OK I got it",
    "Win $$$ now!!! Limited offer!!!",
    "I am not happy with this"
]

all_tokens = []

for s in sentences:
    tokens = preprocess_text(s)
    all_tokens.extend(tokens)

word_freq = Counter(all_tokens)

print("Top 10 Most Frequent Words:")
print(word_freq.most_common(10))

print("\nTop 5 Least Frequent Words:")
least_common = word_freq.most_common()[:-6:-1]
print(least_common)
# Out:
# Top 10 Most Frequent Words:
# [('this', 4), ('now', 3), ('get', 1), ('free', 1), ('access', 1), ('absolutely', 1), ('loved', 1), ('product', 1), ('worst', 1), ('service', 1)]
#
# Top 5 Least Frequent Words:
# [('with', 1), ('happy', 1), ('not', 1), ('offer', 1), ('limited', 1)]

# %% [markdown]
# Task 6: Build Full Pipeline

# %%
import re

def preprocess_text(text):

    text = text.lower()
    text = re.sub(r'http\S+|www\S+', '', text)
    text = re.sub(r'\S+@\S+', '', text)
    text = re.sub(r'\d+', '', text)
    text = re.sub(r'(.)\1{2,}', r'\1', text)
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()

    tokens = text.split()

    filtered_tokens = []
    for word in tokens:
        if len(word) > 2 or word in ["no", "not"]:
            filtered_tokens.append(word)

    cleaned_sentence = " ".join(filtered_tokens)

    return filtered_tokens, cleaned_sentence


def full_pipeline(text_list):

    all_tokens = []
    clean_sentences = []

    for text in text_list:
        tokens, sentence = preprocess_text(text)
        all_tokens.extend(tokens)
        clean_sentences.append(sentence)

    return {
        "tokens": all_tokens,
        "clean_sentences": clean_sentences
    }

# %% [markdown]
# Task 7: Error Handling

# %%
import re

def preprocess_text(text):

    if not isinstance(text, str) or text.strip() == "":
        return [], ""

    text = text.lower()
    text = re.sub(r'http\S+|www\S+', '', text)
    text = re.sub(r'\S+@\S+', '', text)
    text = re.sub(r'\d+', '', text)
    text = re.sub(r'(.)\1{2,}', r'\1', text)
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()

    if text == "":
        return [], ""

    tokens = text.split()

    filtered_tokens = []
    for word in tokens:
        if len(word) > 2 or word in ["no", "not"]:
            filtered_tokens.append(word)

    cleaned_sentence = " ".join(filtered_tokens)

    return filtered_tokens, cleaned_sentence
